# %%
import pandas as pd

coffee_df = pd.read_csv('./data/coffee.csv')
bios_df = pd.read_csv('./data/bios.csv')

# %%
coffee_df.info() #COLUMNS INFO
coffee_df.describe() #STATISTICS INFO
coffee_df.nunique() #NUMBER OF UNIQUES

coffee_df.head(10)
coffee_df.tail(10)

coffee_df[5:10] 
coffee_df["Day"]

coffee_df.loc[[1,2,3], ["Day", "Units Sold"]]
coffee_df.iloc[[1,2,3], [0,1]]

coffee_df.sort_values(["Units Sold", "Coffee Type"], ascending=False)

#Filtering
bios_df[bios_df["born_country"] == "ESP"]
bios_df.loc[bios_df['height_cm'] > 215, ["name", "height_cm"]].head()
bios_df.query("born_country == 'USA' and born_city == 'Seattle'")

#New column
coffee_df["revenue"] = coffee_df["new_price"]*coffee_df["Units Sold"]

#Remove column
coffee_df.drop("price", axis=1, inplace=True)

#Null values
coffee_df.isna().sum()


coffee_df = coffee_df.fillna(0)

coffee_df = coffee_df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# ...
